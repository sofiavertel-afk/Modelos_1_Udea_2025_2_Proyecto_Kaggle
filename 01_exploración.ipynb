# %%
# 🧠 Proyecto UdeA 2025-2
# Exploración inicial de hábitos digitales y rendimiento académico

# 1️⃣ Importar librerías básicas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 2️⃣ Crear un dataset de ejemplo (simulando "train.csv" de Kaggle)
import numpy as np
import pandas as pd

np.random.seed(42)
data = pd.DataFrame({
    "horas_estudio": np.random.normal(3, 1.2, 100),
    "horas_sueno": np.random.normal(7, 1.5, 100),
    "uso_celular_horas": np.random.normal(4, 1.3, 100),
    "rendimiento": np.random.choice(["Alto", "Medio", "Bajo"], 100)
})

data.head()
# Out:
#    horas_estudio  horas_sueno  uso_celular_horas rendimiento
# 0       3.596057     4.876944           4.465124        Alto
# 1       2.834083     6.369032           4.729020       Medio
# 2       3.777226     6.485928           5.407967        Alto
# 3       4.827636     5.796584           5.369943        Alto
# 4       2.719016     6.758071           2.209030        Bajo

# %%
# 3️⃣ Mostrar las primeras filas del dataset
print("📋 Vista inicial de los datos:")
display(data.head())

# 4️⃣ Información general del conjunto de datos
print("\nℹ️ Información general:")
print(data.info())
# Out:
# 📋 Vista inicial de los datos:
#    horas_estudio  horas_sueno  uso_celular_horas rendimiento
# 0       3.596057     4.876944           4.465124        Alto
# 1       2.834083     6.369032           4.729020       Medio
# 2       3.777226     6.485928           5.407967        Alto
# 3       4.827636     5.796584           5.369943        Alto
# 4       2.719016     6.758071           2.209030        Bajo
# ℹ️ Información general:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   horas_estudio      100 non-null    float64
#  1   horas_sueno        100 non-null    float64
#  2   uso_celular_horas  100 non-null    float64
#  3   rendimiento        100 non-null    object
# dtypes: float64(3), object(1)
# memory usage: 3.3+ KB
# None

# %%
# 5️⃣ Estadísticas descriptivas
print("\n📊 Estadísticas descriptivas:")
display(data.describe())

# 6️⃣ Visualización: distribución de horas de estudio
if "horas_estudio" in data.columns:
    plt.figure(figsize=(6,4))
    sns.histplot(data["horas_estudio"], bins=10, kde=True)
    plt.title("Distribución de horas de estudio")
    plt.xlabel("Horas de estudio")
    plt.ylabel("Frecuencia")
    plt.show()
else:
    print("⚠️ No existe la columna 'horas_estudio' en el dataset.")
# Out:
# 📊 Estadísticas descriptivas:
#        horas_estudio  horas_sueno  uso_celular_horas
# count     100.000000   100.000000         100.000000
# mean        2.875384     7.033457           4.084365
# std         1.089802     1.430503           1.409568
# min        -0.143694     4.121843          -0.213648
# 25%         2.278913     5.791509           3.147923
# 50%         2.847652     7.126161           4.127004
# 75%         3.487142     7.807256           4.915769
# max         5.222734    11.080254           9.008551

# %%
# 7️⃣ Relación entre uso del celular y rendimiento
if all(col in data.columns for col in ["rendimiento", "uso_celular_horas"]):
    plt.figure(figsize=(6,4))
    sns.boxplot(x="rendimiento", y="uso_celular_horas", data=data, palette="viridis")
    plt.title("Relación entre uso del celular y rendimiento académico")
    plt.show()
else:
    print("⚠️ Faltan columnas: 'rendimiento' o 'uso_celular_horas'.")
# Out:
# /tmp/ipython-input-2600633781.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="rendimiento", y="uso_celular_horas", data=data, palette="viridis")

# %%
# 8️⃣ Matriz de correlación
cols_corr = [c for c in ["horas_estudio", "horas_sueno", "uso_celular_horas"] if c in data.columns]
if len(cols_corr) >= 2:
    plt.figure(figsize=(5,4))
    sns.heatmap(data[cols_corr].corr(), annot=True, cmap="coolwarm")
    plt.title("Matriz de correlación entre variables numéricas")
    plt.show()
else:
    print("⚠️ No hay suficientes variables numéricas para calcular correlación.")
